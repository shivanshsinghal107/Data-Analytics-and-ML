# %% [markdown]
# 21 PANDAS OPERATIONS

# %%
#read a csv file
import pandas as pd
import numpy as np
df0=pd.read_csv('tmdb_5000_credits.csv')
#same output if df0=pd.read_csv('tmdb_5000_credits.csv',sep=',' ,header=0,index_col=False,names=None)
df0.head(3)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...

# %%
#create dataframe by numpy array
dates=pd.date_range('today',periods=8)
nums=np.random.randn(8,5)
columns=['A1','A2','A3','A4','A5']

#reset an index to an existing column or another list or array
df=pd.DataFrame(nums,index=dates,columns=columns)
df
# Out:
#                                   A1        A2        A3        A4        A5
# 2019-09-08 19:01:03.959298 -0.955318  0.029948  0.116825  1.341275 -1.668134
# 2019-09-09 19:01:03.959298  2.231479 -0.374719 -2.003258 -0.267254  0.690460
# 2019-09-10 19:01:03.959298 -1.469217  1.356730  2.063621  0.375920  0.936682
# 2019-09-11 19:01:03.959298 -0.948231  1.194885 -0.265927  0.455987 -0.110142
# 2019-09-12 19:01:03.959298  1.112978 -1.335538 -0.269149  2.010466  1.646833
# 2019-09-13 19:01:03.959298  1.526413  1.511425  1.090695  0.104673 -0.877477
# 2019-09-14 19:01:03.959298 -0.209336  0.416392  0.354414 -0.596846  0.150292
# 2019-09-15 19:01:03.959298  0.859804 -1.176762  0.482736  0.875144  0.176782

# %%
#create dtaframe by dictionary array
movies={'Name':["The Avengers","Avengers:Age of Ultron","Avengers:Infinity War","Thor Ragnarok","Avengers Endgame","Black Widow"],
     'Year':[2011,2014,2017,2019,2020,2018],'Priority':["Fourth","Fifth","Second","First","Sixth","Third"],'Watched':['Y','Y','Y','Y','N',"Not Released"]}
cols=[1,2,3,4,5,6]

df1=pd.DataFrame(movies,index=cols)
df1
# Out:
#                      Name  Year Priority       Watched
# 1            The Avengers  2011   Fourth             Y
# 2  Avengers:Age of Ultron  2014    Fifth             Y
# 3   Avengers:Infinity War  2017   Second             Y
# 4           Thor Ragnarok  2019    First             Y
# 5        Avengers Endgame  2020    Sixth             N
# 6             Black Widow  2018    Third  Not Released

# %%
#PROBLEM
#number of rows and columns to view
df0[3].tail(4)
#tail-bottom values,head-top values 
#3 is number of columns to view and 4 is rows
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 3
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-15fa6dcc27b2> in <module>
#       1 #PROBLEM
# ...

# %%
#PROBLEMS
#rename one or more columns
df1.rename(columns={'Name':'Movie_Name'},inplace=True)
df1.tail(3)
# Out:
#          Movie_Name  Year Priority       Watched
# 4     Thor Ragnarok  2019    First             Y
# 5  Avengers Endgame  2020    Sixth             N
# 6       Black Widow  2018    Third  Not Released

# %%
#get column names in a list
df0.columns.tolist()
# Out:
# ['movie_id', 'title', 'cast', 'crew']

# %%
#creating a series from a list
array={'Name':["The Avengers","Avengers:Age of Ultron","Avengers:Infinity War","Thor Ragnarok","Avengers Endgame","Black Widow"],
     'Year':[2011,2014,2017,2019,2020,2018],'Priority':["Fourth","Fifth","Second","First","Sixth","Third"],'Watched':['Y','Y','Y','Y','N',"Not Released"]}
list=pd.Series(array)

#PROBLEM
#count frequency of values in a series
list[2].value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-fe4e177de0b0> in <module>
#       6
#       7 #count frequency of values in a series
# ----> 8 list[2].value_counts()
#
# AttributeError: 'list' object has no attribute 'value_counts'

# %%
#create random nparray and change index
import numpy as np
k=np.random.randn(3)
i=['First','Second','Third']
s=pd.Series(k,index=i)
s
# Out:
# First    -0.725506
# Second   -0.094072
# Third    -0.490193
# dtype: float64

# %%
#remove a column
df0.drop('crew',axis=1,inplace=True)
df0.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...

# %%
#change index in a dataframe
df0.set_index('cast',inplace=True)
df0.head()
# Out:
# Empty DataFrame
# Columns: []
# ...
