# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test_data=pd.read_csv('application_test.csv')

# %%
type(test_data)
# Out:
# pandas.core.frame.DataFrame

# %%
test_data.shape
# Out:
# (48744, 121)

# %%
cdr_data=test_data.drop(columns=['SK_ID_CURR','DAYS_BIRTH','DAYS_EMPLOYED',
 'DAYS_REGISTRATION',
 'DAYS_ID_PUBLISH',
 'OWN_CAR_AGE',
 'FLAG_MOBIL',
 'FLAG_EMP_PHONE',
 'FLAG_WORK_PHONE',
 'FLAG_CONT_MOBILE',
 'FLAG_PHONE',
 'FLAG_EMAIL',
 'REGION_RATING_CLIENT',
 'REGION_RATING_CLIENT_W_CITY',
 'WEEKDAY_APPR_PROCESS_START',
 'HOUR_APPR_PROCESS_START',
 'REG_REGION_NOT_LIVE_REGION',
 'REG_REGION_NOT_WORK_REGION',
 'LIVE_REGION_NOT_WORK_REGION',
 'REG_CITY_NOT_LIVE_CITY',
 'REG_CITY_NOT_WORK_CITY',
 'LIVE_CITY_NOT_WORK_CITY',
 'ORGANIZATION_TYPE',
 'EXT_SOURCE_1',
 'EXT_SOURCE_2',
 'EXT_SOURCE_3',
 'APARTMENTS_AVG',
 'BASEMENTAREA_AVG',
 'YEARS_BEGINEXPLUATATION_AVG',
 'YEARS_BUILD_AVG',
 'COMMONAREA_AVG',
 'ELEVATORS_AVG',
 'ENTRANCES_AVG',
 'FLOORSMAX_AVG',
 'FLOORSMIN_AVG',
 'LANDAREA_AVG',
 'LIVINGAPARTMENTS_AVG',
 'LIVINGAREA_AVG',
 'NONLIVINGAPARTMENTS_AVG',
 'NONLIVINGAREA_AVG',
 'APARTMENTS_MODE',
 'BASEMENTAREA_MODE',
 'YEARS_BEGINEXPLUATATION_MODE',
 'YEARS_BUILD_MODE',
 'COMMONAREA_MODE',
 'ELEVATORS_MODE',
 'ENTRANCES_MODE',
 'FLOORSMAX_MODE',
 'FLOORSMIN_MODE',
 'LANDAREA_MODE',
 'LIVINGAPARTMENTS_MODE',
 'LIVINGAREA_MODE',
 'NONLIVINGAPARTMENTS_MODE',
 'NONLIVINGAREA_MODE',
 'APARTMENTS_MEDI',
 'BASEMENTAREA_MEDI',
 'YEARS_BEGINEXPLUATATION_MEDI',
 'YEARS_BUILD_MEDI',
 'COMMONAREA_MEDI',
 'ELEVATORS_MEDI',
 'ENTRANCES_MEDI',
 'FLOORSMAX_MEDI',
 'FLOORSMIN_MEDI',
 'LANDAREA_MEDI',
 'LIVINGAPARTMENTS_MEDI',
 'LIVINGAREA_MEDI',
 'NONLIVINGAPARTMENTS_MEDI',
 'NONLIVINGAREA_MEDI',
 'FONDKAPREMONT_MODE',
 'HOUSETYPE_MODE',
 'TOTALAREA_MODE',
 'WALLSMATERIAL_MODE',
 'EMERGENCYSTATE_MODE',
 'OBS_30_CNT_SOCIAL_CIRCLE',
 'DEF_30_CNT_SOCIAL_CIRCLE',
 'OBS_60_CNT_SOCIAL_CIRCLE',
 'DEF_60_CNT_SOCIAL_CIRCLE',
 'DAYS_LAST_PHONE_CHANGE',
 'FLAG_DOCUMENT_2',
 'FLAG_DOCUMENT_3',
 'FLAG_DOCUMENT_4',
 'FLAG_DOCUMENT_5',
 'FLAG_DOCUMENT_6',
 'FLAG_DOCUMENT_7',
 'FLAG_DOCUMENT_8',
 'FLAG_DOCUMENT_9',
 'FLAG_DOCUMENT_10',
 'FLAG_DOCUMENT_11',
 'FLAG_DOCUMENT_12',
 'FLAG_DOCUMENT_13',
 'FLAG_DOCUMENT_14',
 'FLAG_DOCUMENT_15',
 'FLAG_DOCUMENT_16',
 'FLAG_DOCUMENT_17',
 'FLAG_DOCUMENT_18',
 'FLAG_DOCUMENT_19',
 'FLAG_DOCUMENT_20',
 'FLAG_DOCUMENT_21',
 'AMT_REQ_CREDIT_BUREAU_HOUR',
 'AMT_REQ_CREDIT_BUREAU_DAY',
 'AMT_REQ_CREDIT_BUREAU_WEEK',
 'AMT_REQ_CREDIT_BUREAU_MON',
 'AMT_REQ_CREDIT_BUREAU_QRT',
 'AMT_REQ_CREDIT_BUREAU_YEAR'])
cdr_data
# Out:
#       NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0             Cash loans           F            N               Y
# 1             Cash loans           M            N               Y
# 2             Cash loans           M            Y               Y
# 3             Cash loans           F            N               Y
# 4             Cash loans           M            Y               N
# 5             Cash loans           F            Y               Y
# 6             Cash loans           M            Y               Y
# 7             Cash loans           M            N               Y
# 8             Cash loans           F            N               Y
# 9             Cash loans           F            Y               Y
# 10            Cash loans           F            N               Y
# 11            Cash loans           F            N               Y
# 12            Cash loans           F            N               Y
# ...

# %%
cdr_data.dropna(inplace=True)
cdr_data
# Out:
#       NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 1             Cash loans           M            N               Y
# 3             Cash loans           F            N               Y
# 5             Cash loans           F            Y               Y
# 6             Cash loans           M            Y               Y
# 7             Cash loans           M            N               Y
# 8             Cash loans           F            N               Y
# 9             Cash loans           F            Y               Y
# 11            Cash loans           F            N               Y
# 13            Cash loans           F            Y               Y
# 14       Revolving loans           M            N               Y
# 15            Cash loans           M            Y               Y
# 16            Cash loans           F            Y               Y
# 18            Cash loans           F            Y               Y
# ...

# %%
cdr=cdr_data.drop(columns=['AMT_ANNUITY','AMT_GOODS_PRICE','AMT_CREDIT'])
cdr
# Out:
#       NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 1             Cash loans           M            N               Y
# 3             Cash loans           F            N               Y
# 5             Cash loans           F            Y               Y
# 6             Cash loans           M            Y               Y
# 7             Cash loans           M            N               Y
# 8             Cash loans           F            N               Y
# 9             Cash loans           F            Y               Y
# 11            Cash loans           F            N               Y
# 13            Cash loans           F            Y               Y
# 14       Revolving loans           M            N               Y
# 15            Cash loans           M            Y               Y
# 16            Cash loans           F            Y               Y
# 18            Cash loans           F            Y               Y
# ...

# %%
cdr=cdr_data.drop(columns=['REGION_POPULATION_RELATIVE'])
cdr.boxplot()

# %%
cdr=cdr.drop(columns=['AMT_ANNUITY','AMT_GOODS_PRICE','AMT_CREDIT'])

# %%
cdr.boxplot()

# %%
cdr.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a4d6ada58>,
# ...
#       dtype=object)

# %%
cdr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32545 entries, 1 to 48743
# Data columns (total 13 columns):
# NAME_CONTRACT_TYPE     32545 non-null object
# CODE_GENDER            32545 non-null object
# FLAG_OWN_CAR           32545 non-null object
# FLAG_OWN_REALTY        32545 non-null object
# CNT_CHILDREN           32545 non-null int64
# AMT_INCOME_TOTAL       32545 non-null float64
# NAME_TYPE_SUITE        32545 non-null object
# NAME_INCOME_TYPE       32545 non-null object
# NAME_EDUCATION_TYPE    32545 non-null object
# NAME_FAMILY_STATUS     32545 non-null object
# NAME_HOUSING_TYPE      32545 non-null object
# OCCUPATION_TYPE        32545 non-null object
# CNT_FAM_MEMBERS        32545 non-null float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 3.5+ MB

# %%
cdr.isnull().sum()
# Out:
# NAME_CONTRACT_TYPE     0
# CODE_GENDER            0
# FLAG_OWN_CAR           0
# FLAG_OWN_REALTY        0
# CNT_CHILDREN           0
# AMT_INCOME_TOTAL       0
# NAME_TYPE_SUITE        0
# NAME_INCOME_TYPE       0
# NAME_EDUCATION_TYPE    0
# NAME_FAMILY_STATUS     0
# NAME_HOUSING_TYPE      0
# OCCUPATION_TYPE        0
# CNT_FAM_MEMBERS        0
# dtype: int64

# %%
cdr[cdr.AMT_INCOME_TOTAL > 2000000]   # outliers
# Out:
#       NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 3317          Cash loans           M            N               N
# 3332          Cash loans           F            Y               N
# 41378         Cash loans           F            Y               Y
#
#        CNT_CHILDREN  AMT_INCOME_TOTAL NAME_TYPE_SUITE      NAME_INCOME_TYPE  \
# 3317              1         2250000.0   Unaccompanied               Working
# 3332              0         4410000.0   Unaccompanied  Commercial associate
# 41378             1         3150000.0   Unaccompanied  Commercial associate
#
#       NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 3317    Incomplete higher            Married  House / apartment
# 3332     Higher education          Separated  House / apartment
# 41378    Higher education            Married  House / apartment
#
#       OCCUPATION_TYPE  CNT_FAM_MEMBERS
# 3317         Managers              3.0
# 3332         Managers              1.0
# ...

# %%
cdr.drop([3317,3332,41378],inplace=True)

# %%
cdr.boxplot()

# %%
cdr.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a4d58e390>,
# ...
#       dtype=object)

# %%
print(cdr['NAME_EDUCATION_TYPE'].mode())
print(cdr['OCCUPATION_TYPE'].mode())
# Out:
# 0    Secondary / secondary special
# dtype: object
# 0    Laborers
# dtype: object

# %%
grp = cdr.groupby('OCCUPATION_TYPE')
a = grp['CNT_CHILDREN'].agg(np.sum)
b = grp['AMT_INCOME_TOTAL'].agg(np.mean)
c = grp['CNT_FAM_MEMBERS'].agg(np.sum)
print(a)
print(b)
print(c)
# Out:
# OCCUPATION_TYPE
# Accountants               814
# Cleaning staff            210
# Cooking staff             382
# Core staff               2221
# Drivers                  1349
# HR staff                   46
# High skill tech staff     867
# IT staff                   62
# Laborers                 4126
# Low-skill Laborers        103
# Managers                 1777
# Medicine staff            635
# Private service staff     213
# Realty agents              83
# Sales staff              2280
# Secretaries               108
# Security staff            310
# Waiters/barmen staff       65
# Name: CNT_CHILDREN, dtype: int64
# OCCUPATION_TYPE
# Accountants              207515.990596
# Cleaning staff           144613.397036
# Cooking staff            153001.428571
# Core staff               181781.582615
# Drivers                  196509.321192
# HR staff                 198697.270408
# High skill tech staff    192122.581739
# IT staff                 209494.936709
# ...

# %%
plt.figure(figsize=(16,5))
plt.plot(b,'ro',color='b')
plt.title('OCCUPATION WISE INCOME')
plt.xticks(rotation=90)
plt.xlabel('Occupation Type')
plt.ylabel('Income per Head')
plt.show()

# %%
plt.figure(figsize=(16,5))
plt.plot(b,'r--',color='r')
plt.title('OCCUPATION WISE INCOME')
plt.xticks(rotation=90)
plt.xlabel('Occupation Type')
plt.ylabel('Income per Head')
plt.show()

# %%
plt.figure(figsize=(16,5))
plt.plot(b,'g^',color='g')
plt.title('OCCUPATION WISE INCOME')
plt.xticks(rotation=90)
plt.xlabel('Occupation Type')
plt.ylabel('Income per Head')
plt.show()

# %%
data=pd.read_csv('application_test.csv')
data.drop(columns=['SK_ID_CURR','DAYS_BIRTH','DAYS_EMPLOYED',
 'DAYS_REGISTRATION','CNT_CHILDREN','CNT_FAM_MEMBERS',
 'DAYS_ID_PUBLISH','REGION_POPULATION_RELATIVE',
 'OWN_CAR_AGE',
 'FLAG_MOBIL',
 'FLAG_EMP_PHONE',
 'FLAG_WORK_PHONE',
 'FLAG_CONT_MOBILE',
 'FLAG_PHONE',
 'FLAG_EMAIL',
 'REGION_RATING_CLIENT',
 'REGION_RATING_CLIENT_W_CITY',
 'WEEKDAY_APPR_PROCESS_START',
 'HOUR_APPR_PROCESS_START',
 'REG_REGION_NOT_LIVE_REGION',
 'REG_REGION_NOT_WORK_REGION',
 'LIVE_REGION_NOT_WORK_REGION',
 'REG_CITY_NOT_LIVE_CITY',
 'REG_CITY_NOT_WORK_CITY',
 'LIVE_CITY_NOT_WORK_CITY',
 'ORGANIZATION_TYPE',
 'EXT_SOURCE_1',
 'EXT_SOURCE_2',
 'EXT_SOURCE_3',
 'APARTMENTS_AVG',
 'BASEMENTAREA_AVG',
 'YEARS_BEGINEXPLUATATION_AVG',
 'YEARS_BUILD_AVG',
 'COMMONAREA_AVG',
 'ELEVATORS_AVG',
 'ENTRANCES_AVG',
 'FLOORSMAX_AVG',
 'FLOORSMIN_AVG',
 'LANDAREA_AVG',
 'LIVINGAPARTMENTS_AVG',
 'LIVINGAREA_AVG',
 'NONLIVINGAPARTMENTS_AVG',
 'NONLIVINGAREA_AVG',
 'APARTMENTS_MODE',
 'BASEMENTAREA_MODE',
 'YEARS_BEGINEXPLUATATION_MODE',
 'YEARS_BUILD_MODE',
 'COMMONAREA_MODE',
 'ELEVATORS_MODE',
 'ENTRANCES_MODE',
 'FLOORSMAX_MODE',
 'FLOORSMIN_MODE',
 'LANDAREA_MODE',
 'LIVINGAPARTMENTS_MODE',
 'LIVINGAREA_MODE',
 'NONLIVINGAPARTMENTS_MODE',
 'NONLIVINGAREA_MODE',
 'APARTMENTS_MEDI',
 'BASEMENTAREA_MEDI',
 'YEARS_BEGINEXPLUATATION_MEDI',
 'YEARS_BUILD_MEDI',
 'COMMONAREA_MEDI',
 'ELEVATORS_MEDI',
 'ENTRANCES_MEDI',
 'FLOORSMAX_MEDI',
 'FLOORSMIN_MEDI',
 'LANDAREA_MEDI',
 'LIVINGAPARTMENTS_MEDI',
 'LIVINGAREA_MEDI',
 'NONLIVINGAPARTMENTS_MEDI',
 'NONLIVINGAREA_MEDI',
 'FONDKAPREMONT_MODE',
 'HOUSETYPE_MODE',
 'TOTALAREA_MODE',
 'WALLSMATERIAL_MODE',
 'EMERGENCYSTATE_MODE',
 'OBS_30_CNT_SOCIAL_CIRCLE',
 'DEF_30_CNT_SOCIAL_CIRCLE',
 'OBS_60_CNT_SOCIAL_CIRCLE',
 'DEF_60_CNT_SOCIAL_CIRCLE',
 'DAYS_LAST_PHONE_CHANGE',
 'FLAG_DOCUMENT_2',
 'FLAG_DOCUMENT_3',
 'FLAG_DOCUMENT_4',
 'FLAG_DOCUMENT_5',
 'FLAG_DOCUMENT_6',
 'FLAG_DOCUMENT_7',
 'FLAG_DOCUMENT_8',
 'FLAG_DOCUMENT_9',
 'FLAG_DOCUMENT_10',
 'FLAG_DOCUMENT_11',
 'FLAG_DOCUMENT_12',
 'FLAG_DOCUMENT_13',
 'FLAG_DOCUMENT_14',
 'FLAG_DOCUMENT_15',
 'FLAG_DOCUMENT_16',
 'FLAG_DOCUMENT_17',
 'FLAG_DOCUMENT_18',
 'FLAG_DOCUMENT_19',
 'FLAG_DOCUMENT_20',
 'FLAG_DOCUMENT_21',
 'AMT_REQ_CREDIT_BUREAU_HOUR',
 'AMT_REQ_CREDIT_BUREAU_DAY',
 'AMT_REQ_CREDIT_BUREAU_WEEK',
 'AMT_REQ_CREDIT_BUREAU_MON',
 'AMT_REQ_CREDIT_BUREAU_QRT',
 'AMT_REQ_CREDIT_BUREAU_YEAR'],inplace=True)
data
# Out:
#       NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0             Cash loans           F            N               Y
# 1             Cash loans           M            N               Y
# 2             Cash loans           M            Y               Y
# 3             Cash loans           F            N               Y
# 4             Cash loans           M            Y               N
# 5             Cash loans           F            Y               Y
# 6             Cash loans           M            Y               Y
# 7             Cash loans           M            N               Y
# 8             Cash loans           F            N               Y
# 9             Cash loans           F            Y               Y
# 10            Cash loans           F            N               Y
# 11            Cash loans           F            N               Y
# 12            Cash loans           F            N               Y
# ...

# %%
data.dropna(inplace=True)
data.boxplot()

# %%
data.sort_values(by='AMT_CREDIT',ascending=False)
# Out:
#       NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 45560         Cash loans           F            N               Y
# 5969          Cash loans           F            N               N
# 45211         Cash loans           F            Y               N
# 30653         Cash loans           F            N               Y
# 17578         Cash loans           F            N               Y
# 3641          Cash loans           F            N               N
# 27908         Cash loans           F            Y               Y
# 24598         Cash loans           F            N               Y
# 32248         Cash loans           M            Y               Y
# 18665         Cash loans           M            Y               Y
# 41040         Cash loans           F            Y               N
# 32431         Cash loans           M            N               Y
# 12943         Cash loans           M            N               Y
# ...

# %%
data.sort_values(by='AMT_INCOME_TOTAL',ascending=False)
# Out:
#       NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 3332          Cash loans           F            Y               N
# 41378         Cash loans           F            Y               Y
# 3317          Cash loans           M            N               N
# 21535         Cash loans           M            N               N
# 16931         Cash loans           M            Y               Y
# 9908          Cash loans           F            N               Y
# 13984         Cash loans           F            Y               Y
# 15334         Cash loans           M            Y               Y
# 46173         Cash loans           F            N               Y
# 22575         Cash loans           F            Y               Y
# 5642          Cash loans           M            Y               Y
# 17457         Cash loans           F            Y               Y
# 5880          Cash loans           M            Y               Y
# ...

# %%
data.drop([3332,41378,3317],inplace=True)

# %%
data.boxplot()

# %%
data.drop(columns=['AMT_ANNUITY'],inplace=True)

# %%
data.boxplot()

# %%
gp=data.groupby('OCCUPATION_TYPE')
x=gp['AMT_INCOME_TOTAL'].agg(np.mean)
y=gp['AMT_CREDIT'].agg(np.mean)
z=gp['AMT_GOODS_PRICE'].agg(np.mean)

# %%
plt.figure(figsize=(16,5))
plt.plot(x,'r--',color='b')
plt.title('OCCUPATION WISE INCOME')
plt.xticks(rotation=90)
plt.xlabel('OCCUPATION TYPE')
plt.ylabel('INCOME PER HEAD')
plt.show()

# %%
plt.figure(figsize=(16,5))
plt.plot(y,'r--',color='r')
plt.title('OCCUPATION WISE INCOME')
plt.xticks(rotation=90)
plt.xlabel('OCCUPATION TYPE')
plt.ylabel('CREDIT PER HEAD')
plt.show()

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1f865cbb38>,
# ...
#       dtype=object)

# %%
test=pd.read_csv('application_test.csv')
test.drop(columns=['DAYS_REGISTRATION',
 'DAYS_ID_PUBLISH',
 'OWN_CAR_AGE',
 'FLAG_MOBIL',
 'FLAG_EMP_PHONE',
 'FLAG_WORK_PHONE',
 'FLAG_CONT_MOBILE',
 'FLAG_PHONE',
 'FLAG_EMAIL',
 'REGION_RATING_CLIENT',
 'REGION_RATING_CLIENT_W_CITY',
 'WEEKDAY_APPR_PROCESS_START',
 'HOUR_APPR_PROCESS_START',
 'REG_REGION_NOT_LIVE_REGION',
 'REG_REGION_NOT_WORK_REGION',
 'LIVE_REGION_NOT_WORK_REGION',
 'REG_CITY_NOT_LIVE_CITY',
 'REG_CITY_NOT_WORK_CITY',
 'LIVE_CITY_NOT_WORK_CITY',
 'EXT_SOURCE_1',
 'EXT_SOURCE_2',
 'EXT_SOURCE_3',
 'APARTMENTS_AVG',
 'BASEMENTAREA_AVG',
 'YEARS_BEGINEXPLUATATION_AVG',
 'YEARS_BUILD_AVG',
 'COMMONAREA_AVG',
 'ELEVATORS_AVG',
 'ENTRANCES_AVG',
 'FLOORSMAX_AVG',
 'FLOORSMIN_AVG',
 'LANDAREA_AVG',
 'LIVINGAPARTMENTS_AVG',
 'LIVINGAREA_AVG',
 'NONLIVINGAPARTMENTS_AVG',
 'NONLIVINGAREA_AVG',
 'APARTMENTS_MODE',
 'BASEMENTAREA_MODE',
 'YEARS_BEGINEXPLUATATION_MODE',
 'YEARS_BUILD_MODE',
 'COMMONAREA_MODE',
 'ELEVATORS_MODE',
 'ENTRANCES_MODE',
 'FLOORSMAX_MODE',
 'FLOORSMIN_MODE',
 'LANDAREA_MODE',
 'LIVINGAPARTMENTS_MODE',
 'LIVINGAREA_MODE',
 'NONLIVINGAPARTMENTS_MODE',
 'NONLIVINGAREA_MODE',
 'APARTMENTS_MEDI',
 'BASEMENTAREA_MEDI',
 'YEARS_BEGINEXPLUATATION_MEDI',
 'YEARS_BUILD_MEDI',
 'COMMONAREA_MEDI',
 'ELEVATORS_MEDI',
 'ENTRANCES_MEDI',
 'FLOORSMAX_MEDI',
 'FLOORSMIN_MEDI',
 'LANDAREA_MEDI',
 'LIVINGAPARTMENTS_MEDI',
 'LIVINGAREA_MEDI',
 'NONLIVINGAPARTMENTS_MEDI',
 'NONLIVINGAREA_MEDI',
 'FONDKAPREMONT_MODE',
 'HOUSETYPE_MODE',
 'TOTALAREA_MODE',
 'WALLSMATERIAL_MODE',
 'EMERGENCYSTATE_MODE',
 'OBS_30_CNT_SOCIAL_CIRCLE',
 'DEF_30_CNT_SOCIAL_CIRCLE',
 'OBS_60_CNT_SOCIAL_CIRCLE',
 'DEF_60_CNT_SOCIAL_CIRCLE',
 'DAYS_LAST_PHONE_CHANGE',
 'FLAG_DOCUMENT_2',
 'FLAG_DOCUMENT_3',
 'FLAG_DOCUMENT_4',
 'FLAG_DOCUMENT_5',
 'FLAG_DOCUMENT_6',
 'FLAG_DOCUMENT_7',
 'FLAG_DOCUMENT_8',
 'FLAG_DOCUMENT_9',
 'FLAG_DOCUMENT_10',
 'FLAG_DOCUMENT_11',
 'FLAG_DOCUMENT_12',
 'FLAG_DOCUMENT_13',
 'FLAG_DOCUMENT_14',
 'FLAG_DOCUMENT_15',
 'FLAG_DOCUMENT_16',
 'FLAG_DOCUMENT_17',
 'FLAG_DOCUMENT_18',
 'FLAG_DOCUMENT_19',
 'FLAG_DOCUMENT_20',
 'FLAG_DOCUMENT_21',
 'AMT_REQ_CREDIT_BUREAU_HOUR',
 'AMT_REQ_CREDIT_BUREAU_DAY',
 'AMT_REQ_CREDIT_BUREAU_WEEK',
 'AMT_REQ_CREDIT_BUREAU_MON',
 'AMT_REQ_CREDIT_BUREAU_QRT',
 'AMT_REQ_CREDIT_BUREAU_YEAR'],inplace=True)
